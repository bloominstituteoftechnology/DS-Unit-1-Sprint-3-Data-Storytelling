# %% [markdown]
# <a href="https://colab.research.google.com/github/danhorsley/danhorsley-DS-Unit-1-Sprint-3-Data-Storytelling/blob/master/Copy_of_LS_DS_222_Choose_appropriate_visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# _Lambda School Data Science_
# # Choose appropriate visualizations
#
# Objectives
# - fix misleading visualizations
# - use Seaborn to visualize distributions and relationships with continuous and discrete variables
#
# Links
# - [How to Spot Visualization Lies](https://flowingdata.com/2017/02/09/how-to-spot-visualization-lies/)
# - [Visual Vocabulary - Vega Edition](http://ft.com/vocabulary)
# - [Choosing a Python Visualization Tool flowchart](http://pbpython.com/python-vis-flowchart.html)
# - [Searborn example gallery](http://seaborn.pydata.org/examples/index.html) & [tutorial](http://seaborn.pydata.org/tutorial.html)

# %% [markdown]
# # Upgrade Seaborn
#
# Make sure you have at least version 0.9.0.
#
# On Colab, go to **Restart runtime** after you run the `pip` command.

# %%
# !pip install --upgrade seaborn
# Out:
# Requirement already up-to-date: seaborn in /usr/local/lib/python3.6/dist-packages (0.9.0)
# ...

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.9.0'

# %%
1+1 # to make difference
# Out:
# 2

# %% [markdown]
# # Fix misleading visualizations

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/LambdaSchool/DS-Unit-1-Sprint-3-Data-Storytelling/master/module2-choose-appropriate-visualizations/misleading.py
    
import misleading
# Out:
# --2019-04-02 16:26:11--  https://raw.githubusercontent.com/LambdaSchool/DS-Unit-1-Sprint-3-Data-Storytelling/master/module2-choose-appropriate-visualizations/misleading.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1258 (1.2K) [text/plain]
# Saving to: ‘misleading.py’
#
# misleading.py       100%[===================>]   1.23K  --.-KB/s    in 0s
#
# 2019-04-02 16:26:12 (164 MB/s) - ‘misleading.py’ saved [1258/1258]

# %% [markdown]
# ### Fix misleading plot #1

# %%
misleading.plot1();

# %%
insurance = pd.DataFrame(
    index=['State Farm', 'GEICO'], 
    data={'Market Share %': [18.07, 12.79]})

insurance.plot.bar(ylim=(0, 20))

# %% [markdown]
# ### Fix misleading plot #2

# %%
misleading.plot2();

# %%
other = pd.DataFrame(index=['Other'],data={'Market Share %':[100 - 18.07 - 12.79]})

insurance =insurance.append(other)
insurance
# Out:
#             Market Share %
# State Farm           18.07
# GEICO                12.79
# Other                69.14

# %%
insurance.plot.pie('Market Share %', figsize=(5, 5))

# %% [markdown]
# ## Fix misleading plot #3

# %% [markdown]
# _If you're on Jupyter (not Colab) then uncomment and run this cell below:_

# %%
# import altair as alt
# alt.renderers.enable('notebook')

# %%
misleading.plot3()
# Out:
# Chart({
#   data: UrlData({
#     format: TopoDataFormat({
#       feature: 'states',
#       type: 'topojson'
#     }),
#     url: 'https://vega.github.io/vega-datasets/data/us-10m.json'
#   }),
#   encoding: EncodingWithFacet({
#     color: Color({
#       shorthand: 'State Farm policy premiums',
#       type: 'quantitative'
#     })
#   }),
#   height: 300,
#   mark: 'geoshape',
#   projection: Projection({
#     type: 'albersUsa'
#   }),
#   transform: [LookupTransform({
#     from: LookupData({
#       data:                    state  id  State Farm policy premiums  \
#       0                Alabama   1                      768213
#       1                 Alaska   2                      128613
#       2                Arizona   4                      760003
#       3               Arkansas   5                      454931
#       4             California   6                     3655463
#       5               Colorado   8                      827143
# ...

# %%
url = 'https://raw.githubusercontent.com/LambdaSchool/DS-Sprint-02-Storytelling-With-Data/master/module2-choose-appropriate-visualizations/direct_written_premium_by_state_by_group_private_passenger_auto.csv'
df = pd.read_csv(url)

# %%
df.rename(columns={'STATE FARM GRP': 'State Farm policy premiums'}, inplace=True)
df.head()
# Out:
#         state  id  State Farm policy premiums  BERKSHIRE HATHAWAY GRP  \
# 0     Alabama   1                      768213                  282947
# 1      Alaska   2                      128613                   81366
# 2     Arizona   4                      760003                  604049
# 3    Arkansas   5                      454931                   96908
# 4  California   6                     3655463                 2091720
#
#    STATE TOTAL
# 0      3025561
# 1       454623
# 2      4373055
# 3      1777917
# 4     25255501

# %%
(df['State Farm policy premiums'] + df['BERKSHIRE HATHAWAY GRP'] == df['STATE TOTAL']).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df['State Farm market share %'] = df['State Farm policy premiums'] / df['STATE TOTAL']
df.head()
# Out:
#         state  id  State Farm policy premiums  BERKSHIRE HATHAWAY GRP  \
# 0     Alabama   1                      768213                  282947
# 1      Alaska   2                      128613                   81366
# 2     Arizona   4                      760003                  604049
# 3    Arkansas   5                      454931                   96908
# 4  California   6                     3655463                 2091720
#
#    STATE TOTAL  State Farm market share %
# 0      3025561                   0.253908
# 1       454623                   0.282900
# 2      4373055                   0.173792
# 3      1777917                   0.255879
# 4     25255501                   0.144739

# %%
import altair as alt
from vega_datasets import data

states = alt.topo_feature(data.us_10m.url, 'states')
variable = 'State Farm market share %'

alt.Chart(states).mark_geoshape().encode(
    alt.Color(variable, type='quantitative')
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(df, 'id', [variable])
).properties(
    width=500,
    height=300
).project(
    type='albersUsa'
)
# Out:
# Chart({
#   data: UrlData({
#     format: TopoDataFormat({
#       feature: 'states',
#       type: 'topojson'
#     }),
#     url: 'https://vega.github.io/vega-datasets/data/us-10m.json'
#   }),
#   encoding: EncodingWithFacet({
#     color: Color({
#       shorthand: 'State Farm market share %',
#       type: 'quantitative'
#     })
#   }),
#   height: 300,
#   mark: 'geoshape',
#   projection: Projection({
#     type: 'albersUsa'
#   }),
#   transform: [LookupTransform({
#     from: LookupData({
#       data:                    state  id  State Farm policy premiums  \
#       0                Alabama   1                      768213
#       1                 Alaska   2                      128613
#       2                Arizona   4                      760003
#       3               Arkansas   5                      454931
#       4             California   6                     3655463
#       5               Colorado   8                      827143
# ...

# %% [markdown]
# # Use Seaborn to visualize distributions and relationships with continuous and discrete variables

# %% [markdown]
# ## 1. Anscombe dataset

# %% [markdown]
# ### Load dataset

# %%
df = sns.load_dataset('anscombe')

# %% [markdown]
# ### See the data's shape

# %%
df.shape
# Out:
# (44, 3)

# %% [markdown]
# ### See the data

# %%
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# ### [Group by](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html) `'dataset'`

# %%
groups = df.groupby('dataset')

# %% [markdown]
# ### [Describe](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html) the groups

# %%
groups.describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %% [markdown]
# ### Get the [count](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.count.html), for each column in each group

# %%
groups.count()
# Out:
#           x   y
# dataset
# I        11  11
# II       11  11
# III      11  11
# IV       11  11

# %% [markdown]
# ### Get the [mean](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.mean.html) ...

# %%
groups.mean()
# Out:
#            x         y
# dataset
# I        9.0  7.500909
# II       9.0  7.500909
# III      9.0  7.500000
# IV       9.0  7.500909

# %% [markdown]
# ### Get the [standard deviation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.std.html) ...

# %%
groups.std()
# Out:
#                 x         y
# dataset
# I        3.316625  2.031568
# II       3.316625  2.031657
# III      3.316625  2.030424
# IV       3.316625  2.030579

# %% [markdown]
# ### Get the [correlation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.corr.html) ...

# %%
groups.corr()
# Out:
#                   x         y
# dataset
# I       x  1.000000  0.816421
#         y  0.816421  1.000000
# II      x  1.000000  0.816237
#         y  0.816237  1.000000
# III     x  1.000000  0.816287
#         y  0.816287  1.000000
# IV      x  1.000000  0.816521
#         y  0.816521  1.000000

# %% [markdown]
# ### Use pandas to [plot](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html) the groups, as scatter plots

# %%
groups.plot('x','y',kind='scatter');
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ### Use Seaborn to make [relational plots](http://seaborn.pydata.org/generated/seaborn.relplot.html)

# %%
sns.relplot('x', 'y', col='dataset', data=df, col_wrap=2)

# %% [markdown]
# ### Use Seaborn to make [linear model plots](http://seaborn.pydata.org/generated/seaborn.lmplot.html)

# %%
sns.lmplot('x', 'y', col='dataset', hue='dataset', data=df)

# %% [markdown]
# #### Links
# - [Seaborn examples: Anscombe's quartet](http://seaborn.pydata.org/examples/anscombes_quartet.html)
# - [Wikipedia: Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet)
# - [The Datasaurus Dozen](https://www.autodeskresearch.com/publications/samestats)

# %% [markdown]
# ## 2. Tips dataset

# %% [markdown]
# ### Load dataset

# %%
tips = sns.load_dataset('tips')

# %% [markdown]
# ### See the data's shape

# %%
tips.shape
# Out:
# (244, 7)

# %% [markdown]
# ### See the first 5 rows

# %%
tips.head()
# Out:
#    total_bill   tip     sex  smoker  day    time  size
# 0       16.99  1.01  Female       0  Sun  Dinner     2
# 1       10.34  1.66    Male       0  Sun  Dinner     3
# 2       21.01  3.50    Male       0  Sun  Dinner     3
# 3       23.68  3.31    Male       0  Sun  Dinner     2
# 4       24.59  3.61  Female       0  Sun  Dinner     4

# %% [markdown]
# ### Describe the data

# %%
tips.describe()
# Out:
#        total_bill         tip      smoker        size
# count  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    0.381148    2.569672
# std      8.902412    1.383638    0.486667    0.951100
# min      3.070000    1.000000    0.000000    1.000000
# 25%     13.347500    2.000000    0.000000    2.000000
# 50%     17.795000    2.900000    0.000000    2.000000
# 75%     24.127500    3.562500    1.000000    3.000000
# max     50.810000   10.000000    1.000000    6.000000

# %%
tips['smoker'] = np.where(tips['smoker']=='Yes',1,0)

# %% [markdown]
# ### Make univariate [distribution plots](https://seaborn.pydata.org/generated/seaborn.distplot.html)

# %%
sns.distplot(tips.tip)

# %%
sns.distplot(tips.total_bill)

# %%
tips['percent'] = tips.tip/tips.total_bill
sns.distplot(tips.percent)

# %%
tips.percent.value_counts(bins=20).sort_index()
# Out:
# (0.034, 0.0694]     6
# (0.0694, 0.103]    25
# (0.103, 0.137]     42
# (0.137, 0.171]     78
# (0.171, 0.204]     60
# (0.204, 0.238]     20
# (0.238, 0.272]      7
# (0.272, 0.306]      3
# (0.306, 0.339]      1
# (0.339, 0.373]      0
# (0.373, 0.407]      0
# (0.407, 0.44]       1
# (0.44, 0.474]       0
# (0.474, 0.508]      0
# (0.508, 0.542]      0
# (0.542, 0.575]      0
# (0.575, 0.609]      0
# (0.609, 0.643]      0
# (0.643, 0.677]      0
# (0.677, 0.71]       1
# Name: percent, dtype: int64

# %% [markdown]
# ### Make bivariate [relational plots](https://seaborn.pydata.org/generated/seaborn.relplot.html)

# %%
sns.relplot('total_bill','tip',data = tips,alpha=0.5)

# %%
sns.relplot('total_bill','percent',data = tips,alpha=0.5)

# %% [markdown]
# ### Make univariate [categorical plots](https://seaborn.pydata.org/generated/seaborn.catplot.html)

# %%
tips.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips.sex.value_counts().plot.bar()

# %%
sns.catplot('day',data=tips, kind='count');

# %% [markdown]
# ### Make bivariate [categorical plots](https://seaborn.pydata.org/generated/seaborn.catplot.html)

# %%
sns.catplot('sex','percent',data=tips, kind = 'strip', alpha = 0.5)

# %% [markdown]
# ## 3. Flights

# %% [markdown]
# ### Load dataset

# %%
flights = sns.load_dataset('flights')

# %% [markdown]
# ### See the data's shape

# %%
flights.shape
# Out:
# (144, 3)

# %% [markdown]
# ### See the first 5 rows

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %% [markdown]
# ### Describe the data

# %%
flights.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %% [markdown]
# ### Plot year & passengers

# %%
sns.relplot('year','passengers',data=flights,kind = 'scatter')

# %%
sns.relplot('year', 'passengers', data=flights, kind='line', ci=95);

# %% [markdown]
# ### Plot month & passengers

# %%
sns.relplot('month', 'passengers', data=flights, kind='line', ci=95);

# %% [markdown]
# ### Create a [pivot table](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.pivot_table.html) of passengers by month and year

# %%
table = flights.pivot_table('passengers','month','year')

# %% [markdown]
# ### Plot the pivot table as a [heat map](https://seaborn.pydata.org/generated/seaborn.heatmap.html)

# %%
plt.figure(figsize=(16,9))
sns.heatmap(table,annot=True, fmt='d');

# %% [markdown]
# # ASSIGNMENT
#
# ### 1.
#
# Replicate the lesson code. I recommend that you [do not copy-paste](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit).
#
# ### 2.
#
# Choose a chart you want to make, from [Visual Vocabulary - Vega Edition](http://ft.com/vocabulary).
#
# Find the chart in an example gallery of a Python data visualization library:
# - [Seaborn](http://seaborn.pydata.org/examples/index.html)
# - [Altair](https://altair-viz.github.io/gallery/index.html)
# - [Matplotlib](https://matplotlib.org/gallery.html)
# - [Pandas](https://pandas.pydata.org/pandas-docs/stable/visualization.html)
#
# Reproduce the chart. [Optionally, try the "Ben Franklin Method."](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit) If you want, experiment and make changes.
#
# Take notes. Consider sharing your work with your cohort!

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-635727e2-b683-4dbc-92c5-612c3eae680c" name="files[]" multiple disabled />
#      <output id="result-635727e2-b683-4dbc-92c5-612c3eae680c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving nobel_prize_by_winner.csv to nobel_prize_by_winner.csv

# %%
nobel_prize = pd.read_csv('nobel_prize_by_winner.csv', encoding = "ISO-8859-1")

# %%
nobel_prize.head(11)
# Out:
#      id         firstname     surname       born       died  \
# 0   846            Elinor      Ostrom 1933-08-07 2012-06-12
# 1   846            Elinor      Ostrom 1933-08-07 2012-06-12
# 2   783      Wangari Muta     Maathai 1940-04-01 2011-09-25
# 3   230  Dorothy Crowfoot     Hodgkin 1910-05-12 1994-07-29
# 4   918            Youyou          Tu 1930-12-30 2019-04-02
# 5   428           Barbara  McClintock 1902-06-16 1992-09-02
# 6   773            Shirin       Ebadi 1947-06-21 2019-04-02
# 7   597            Grazia     Deledda 1871-09-27 1936-08-15
# 8   615          Gabriela     Mistral 1889-04-07 1957-01-10
# 9   782          Elfriede     Jelinek 1946-10-20 2019-04-02
# 10  553  Aung San Suu Kyi         NaN 1945-06-19 2019-04-02
#
#             bornCountry bornCountryCode              bornCity     diedCountry  \
# 0                   USA              US       Los Angeles, CA             USA
# 1                   USA              US       Los Angeles, CA             USA
# ...

# %%
nobel_prize['died'] = nobel_prize['died'].str.replace('0000-00-00','4/2/2019')

# %%
#nobel_prize['born'] = pd.to_datetime(nobel_prize['born'], infer_datetime_format=True)
nobel_prize = nobel_prize[nobel_prize['born'] != '0000/00/00']

# %%
#finding out which entries are causing problems on pd.to datetime


for date in nobel_prize['born']:
  try :
    pd.to_datetime(date,infer_datetime_format=True)
    
    print('ok')
  except:
    print(date)

# %%
nobel_prize[nobel_prize['born']=='00/00/1943']
# Out:
#       id   firstname surname        born  died bornCountry bornCountryCode  \
# 506  745  A. Michael  Spence  00/00/1943   NaN         USA              US
#
#           bornCity diedCountry diedCountryCode diedCity gender    year  \
# 506  Montclair, NJ         NaN             NaN      NaN   male  2001.0
#
#       category overallMotivation  share  \
# 506  economics               NaN    3.0
#
#                                             motivation                 name  \
# 506  "for their analyses of markets with asymmetric...  Stanford University
#
#              city country
# 506  Stanford, CA     USA

# %%
nobel_prize[nobel_prize['born']=='00/00/1898']
# Out:
#       id    firstname surname        born  died  \
# 945  519  Albert John  Lutuli  00/00/1898   NaN
#
#                           bornCountry bornCountryCode  bornCity   diedCountry  \
# 945  Southern Rhodesia (now Zimbabwe)              ZW  Bulawayo  South Africa
#
#     diedCountryCode diedCity gender    year category overallMotivation  share  \
# 945              ZA  Stanger   male  1960.0    peace               NaN    1.0
#
#     motivation name city country
# 945        NaN  NaN  NaN     NaN

# %%
nobel_prize[nobel_prize['born']=='00/00/1943']

# %%
nobel_prize.at[ 506,'born'] = '1/1/1943'
nobel_prize.at[ 945,'born'] = '1/1/1898'

# %%
nobel_prize['born'] = pd.to_datetime(nobel_prize['born'], infer_datetime_format=True)
nobel_prize['died'] = pd.to_datetime(nobel_prize['died'], infer_datetime_format=True)
nobel_prize['year'] = pd.to_datetime(nobel_prize['year'], infer_datetime_format=True)

# %%
nobel_prize['full_name'] =nobel_prize[['firstname', 'surname']].apply(lambda x: ' '.join(x), axis=1)

# %%
#now trying to plot a priestly timeline of birth and death dates of all nobel prize winners




plot_frame = nobel_prize[['full_name','born','died']].copy()
plot_frame = plot_frame.dropna()
plot_frame = plot_frame.sort_values(by='born')
plot_frame=plot_frame.reset_index(drop=True)

# %%
fig, ax = plt.subplots()

x = plot_frame['born'] 
y = plot_frame['full_name']
z = plot_frame['new_died']
mindate = plot_frame['born'].min()
maxdate = plot_frame['new_died'].max()
born_plot = ax.plot_date(x, y, markerfacecolor='CornflowerBlue', markeredgecolor='white')
died_plot = ax.plot_date(z, y, markerfacecolor='darkred', markeredgecolor='white')
fig.autofmt_xdate()
ax.set_xlim([mindate,maxdate])
#ax.set_xlim(['Christian Matthias Theodor Mommsen','Malala Yousafzai'])
ax.figure.set_size_inches(12, 150)

# %%
nobel_prize['surname'] = nobel_prize['surname'].fillna('')

# %%
nobel_prize['born'].isna().sum()
# Out:
# 26

# %%
plot_frame.head(50)

# %%
plot_frame[plot_frame['full_name']=='Theodore William Richards']
# Out:
#                      full_name       born       died
# 119  Theodore William Richards 1868-01-31 2028-04-02

# %%
plot_frame['lifetime']=plot_frame['died']-plot_frame['born']

# %%
plot_frame['lifetime'][plot_frame['full_name']=='Theodore William Richards'] > pd.Timedelta(40000, unit='d')
# Out:
# 119    False
# Name: lifetime, dtype: bool

# %%
#this is to adjust all teh dates where datetime put the wrong century on the year
plot_frame['new_died']=np.where(plot_frame['lifetime']>pd.Timedelta(40000, unit='d'),plot_frame['died']-pd.Timedelta(36525, unit='d'),plot_frame['died'])

# %%
plot_frame[-5:]
# Out:
#                 full_name       born       died   lifetime   new_died
# 924         Adam G. Riess 1969-12-16 2019-04-02 18004 days 2019-04-02
# 925         Leymah Gbowee 1972-02-01 2019-04-02 17227 days 2019-04-02
# 926  Konstantin Novoselov 1974-08-23 2019-04-02 16293 days 2019-04-02
# 927       Tawakkol Karman 1979-02-07 2019-04-02 14664 days 2019-04-02
# 928      Malala Yousafzai 1997-07-12 2019-04-02  7934 days 2019-04-02
