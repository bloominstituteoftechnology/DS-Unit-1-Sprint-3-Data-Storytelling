# %% [markdown]
# <a href="https://colab.research.google.com/github/RecursiveOuroboros/DS-Unit-1-Sprint-3-Data-Storytelling/blob/master/Jason_Meil_DS3_1_3_2_Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade seaborn
# Out:
# Requirement already up-to-date: seaborn in /usr/local/lib/python3.6/dist-packages (0.9.0)
# ...

# %%
import seaborn as sns

# %%
print(sns.__version__)
# Out:
# 0.9.0

# %%
import matplotlib.pyplot as plt
import pandas_datareader.data as web

start = '2018-04-08'
end = '2019-04-07'
df = web.DataReader(name='AMZN', data_source='iex', start=start, end=end)
df
# Out:
#                open     high      low    close    volume
# date
# 2018-04-09  1425.03  1438.48  1402.57  1406.08   4208206
# 2018-04-10  1431.99  1438.38  1415.70  1436.22   4280144
# 2018-04-11  1439.44  1448.78  1424.89  1427.05   3582533
# 2018-04-12  1439.50  1452.12  1435.06  1448.50   3135027
# 2018-04-13  1449.14  1459.78  1424.52  1430.79   3685267
# 2018-04-16  1445.00  1447.00  1427.48  1441.50   2808624
# 2018-04-17  1462.30  1507.19  1457.02  1503.83   5114403
# 2018-04-18  1514.65  1533.80  1504.11  1527.84   5227509
# 2018-04-19  1543.22  1568.52  1539.06  1556.91   6523728
# 2018-04-20  1561.20  1561.20  1516.09  1527.49   5541622
# 2018-04-23  1546.69  1548.00  1503.41  1517.86   4465424
# 2018-04-24  1535.80  1539.50  1448.45  1460.09   7494699
# 2018-04-25  1458.00  1469.99  1415.02  1460.17   6587290
# 2018-04-26  1485.01  1529.42  1478.50  1517.96   8801101
# 2018-04-27  1634.01  1638.10  1567.39  1572.62  13053241
# ...

# %%
df.reset_index(level=0, inplace=True)

# %%
df
# Out:
#            date     open     high      low    close    volume
# 0    2018-04-09  1425.03  1438.48  1402.57  1406.08   4208206
# 1    2018-04-10  1431.99  1438.38  1415.70  1436.22   4280144
# 2    2018-04-11  1439.44  1448.78  1424.89  1427.05   3582533
# 3    2018-04-12  1439.50  1452.12  1435.06  1448.50   3135027
# 4    2018-04-13  1449.14  1459.78  1424.52  1430.79   3685267
# 5    2018-04-16  1445.00  1447.00  1427.48  1441.50   2808624
# 6    2018-04-17  1462.30  1507.19  1457.02  1503.83   5114403
# 7    2018-04-18  1514.65  1533.80  1504.11  1527.84   5227509
# 8    2018-04-19  1543.22  1568.52  1539.06  1556.91   6523728
# 9    2018-04-20  1561.20  1561.20  1516.09  1527.49   5541622
# 10   2018-04-23  1546.69  1548.00  1503.41  1517.86   4465424
# 11   2018-04-24  1535.80  1539.50  1448.45  1460.09   7494699
# 12   2018-04-25  1458.00  1469.99  1415.02  1460.17   6587290
# 13   2018-04-26  1485.01  1529.42  1478.50  1517.96   8801101
# ...

# %%
df.dtypes
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# dtype: object

# %%
import pandas as pd

# %%
df["date"]= pd.to_datetime(df["date"])

# %%
df.shape
# Out:
# (251, 6)

# %%
df.describe()
# Out:
#               open         high          low        close        volume
# count   251.000000   251.000000   251.000000   251.000000  2.510000e+02
# mean   1708.341474  1727.185817  1685.794104  1706.891076  5.371427e+06
# std     146.877774   143.970320   147.751245   145.572837  2.373375e+06
# min    1346.000000  1396.030000  1307.000000  1343.960000  2.115639e+06
# 25%    1609.735000  1625.770000  1594.030000  1609.615000  3.630584e+06
# 50%    1682.700000  1701.570000  1665.000000  1686.220000  4.772866e+06
# 75%    1811.885000  1829.125000  1791.250000  1813.365000  6.515334e+06
# max    2038.110000  2050.500000  2013.000000  2039.510000  1.496378e+07

# %%
sns.scatterplot(x='close', y='volume', data=df)

# %%
sns.lineplot(x='date', y='close', data=df)

# %%
sns.swarmplot(x='date', y='close', hue='volume', data=df)
